# %%
import pandas as pd

# %% [markdown]
# DB from @JoeSchroeNFT:
#
# https://docs.google.com/spreadsheets/d/1uj_RkwcraJZc0cJitcf9lvBJjnz-vveWdfiV8lgljC8/edit#gid=0

# %%
sheet_id = '1uj_RkwcraJZc0cJitcf9lvBJjnz-vveWdfiV8lgljC8'
sheet_name = 'Ballerz%20Database'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
dat=pd.read_csv(url)

# %%
l=['ID',
   'Body',
   'Team',
   'Gender',
   'Accessory Group',
   'Accessory 1',
   'Accessory 2',
   'Accessory 3',
   'Jersey',
   'Hair',
   'Role',
   'Number',
   'Dunks',
   'Shooting',
   'Playmaking',
   'Defense',
   'Overall',
   'Pts',
   'Reb',
   'Ast',
   'Stl',
   'MVP?',
   'JSA Rarity Score',
   'JSA Rarity Rank']

dat_clean=dat[l].fillna('')
dat_clean.head(3)
# Out:
#      ID   Body       Team Gender Accessory Group Accessory 1 Accessory 2  \
# 0  7353  Human  All-Stars      M            None        None
# 1  2284  Human  All-Stars      M            None        None
# 2  5316  Human  All-Stars      M            None        None
#
#   Accessory 3 Jersey    Hair  ... Playmaking  Defense  Overall   Pts   Reb  \
# 0               Home  Custom  ...         99       99     99.0  40.0  16.0
# 1               Home  Custom  ...         99       99     99.0  40.0  16.0
# 2               Home  Custom  ...         99       99     99.0  40.0  16.0
#
#     Ast  Stl  MVP?  JSA Rarity Score  JSA Rarity Rank
# 0  14.0  4.0  True            742.68                1
# 1  14.0  4.0  True            742.49                2
# 2  14.0  4.0  True            742.49                2
#
# [3 rows x 24 columns]
